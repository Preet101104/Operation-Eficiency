# %%
import speech_recognition as sr
import pyttsx3
from transformers import pipeline

# %%
import pathlib
import textwrap

import google.generativeai as genai

from IPython.display import display
from IPython.display import Markdown


def to_markdown(text):
  text = text.replace('•', '  *')
  return Markdown(textwrap.indent(text, '> ', predicate=lambda _: True))

# %%
pip install google
# Out:
# Requirement already satisfied: google in c:\users\preet\appdata\local\programs\python\python311\lib\site-packages (3.0.0)
# Requirement already satisfied: beautifulsoup4 in c:\users\preet\appdata\local\programs\python\python311\lib\site-packages (from google) (4.12.3)
# Requirement already satisfied: soupsieve>1.2 in c:\users\preet\appdata\local\programs\python\python311\lib\site-packages (from beautifulsoup4->google) (2.5)
# Note: you may need to restart the kernel to use updated packages.

# %%
from claude_api import Client

# %%
from claude import claude_client

# %%
from claude import claude_wrapper

# %%
# Preet
client = claude_client.ClaudeClient('Put you api key here')

# %%
organizations = client.get_organizations()
# You can omit passing in the organization uuid and the wrapper will assume
# you will use the first organization instead.
claude_obj = claude_wrapper.ClaudeWrapper(client, organization_uuid=organizations[0]['uuid'])

# %%
new_conversation_data = claude_obj.start_new_conversation("New Conversation", "Hi Claude!")
conversation_uuid = new_conversation_data['uuid']
# You can get the response from the initial message you sent with:
initial_response = new_conversation_data['response']
# You can get the title of the new chat you created with this:
chat_title = new_conversation_data['title']
# Out:
# [17-Mar-24 12:15:48:root:WARNING][claude_client.py:279 - get_conversations_from_org() ] Failed response object: Response(ok=False, data=b'', status_code=None, error='HTTP Error 403: Forbidden')

# %%
conversation_uuid = claude_obj.get_conversations()[0]['uuid']
# Out:
# [17-Mar-24 12:15:49:root:WARNING][claude_client.py:279 - get_conversations_from_org() ] Failed response object: Response(ok=False, data=b'', status_code=None, error='HTTP Error 403: Forbidden')
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 conversation_uuid = claude_obj.get_conversations()[0]['uuid']
#
# TypeError: 'NoneType' object is not subscriptable

# %%
# Python program to translate
# speech to text and text to speech

import speech_recognition as sr
import pyttsx3

# Initialize the recognizer
r = sr.Recognizer()

# Function to convert text to speech
def SpeakText(command):
    # Initialize the engine
    engine = pyttsx3.init()
    engine.say(command)
    engine.runAndWait()

# Exception handling to handle exceptions at runtime
try:
    # use the microphone as source for input.
    with sr.Microphone() as source:
        # wait for a second to let the recognizer
        # adjust the energy threshold based on
        # the surrounding noise level
        r.adjust_for_ambient_noise(source, duration=0.2)

        # Listens for the user's input
        audio = r.listen(source)

        # Using Google to recognize audio
        MyText = r.recognize_google(audio)
        MyText = MyText.lower()

        print("Did you say:", MyText)
        SpeakText(MyText)

        # Assuming `claude_obj` and `conversation_uuid` are defined elsewhere
        response = claude_obj.send_message(MyText, conversation_uuid=conversation_uuid)
        x = response['completion']
        SpeakText(x)  # Corrected indentation here
        print(x)

except sr.UnknownValueError:
    print("Google Speech Recognition could not understand audio")
except sr.RequestError as e:
    print("Could not request results from Google Speech Recognition service; {0}".format(e))
# Out:
# Did you say: can you name three states of india
#  Certainly, here are three states of India:
#
# 1. Maharashtra
# 2. Uttar Pradesh
# 3. Tamil Nadu
